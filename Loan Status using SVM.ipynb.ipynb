# %%
# ------------------------------------------------------------------
# Build the Support Vector Classifier Model
# Predict the loan approval status based on 
# Gender, Marital Status, Credit History, Income and Loan Amount
# ------------------------------------------------------------------

# Import Libraries and read csv file
# Import Libraries and read csv file
import pandas as pd 
dataset=pd.read_csv('01Exercise1.csv')
datasetPrep=dataset.copy()
datasetPrep
# Out:
#      gender married   ch  income  loanamt status
# 0      Male      No  1.0    5849      NaN      Y
# 1      Male     Yes  1.0    4583    128.0      N
# 2      Male     Yes  1.0    3000     66.0      Y
# 3      Male     Yes  1.0    2583    120.0      Y
# 4      Male      No  1.0    6000    141.0      Y
# ..      ...     ...  ...     ...      ...    ...
# 609  Female      No  1.0    2900     71.0      Y
# 610    Male     Yes  1.0    4106     40.0      Y
# 611    Male     Yes  1.0    8072    253.0      Y
# 612    Male     Yes  1.0    7583    187.0      Y
# 613  Female      No  0.0    4583    133.0      N
#
# [614 rows x 6 columns]

# %%
#find out columns with missing values
datasetPrep.isnull().sum(axis=0)
# Out:
# gender     13
# married     3
# ch         50
# income      0
# loanamt    22
# status      0
# dtype: int64

# %%
# Replace Missing Values. Drop the rows.
datasetPrep = datasetPrep.dropna()

# %%
# Drop irrelevant columns based on business sense
datasetPrep = datasetPrep.drop(['gender'], axis=1)

# %%
# Create Dummy variables
datasetPrep.dtypes
datasetPrep = pd.get_dummies(datasetPrep, drop_first=True)
datasetPrep
# Out:
#       ch  income  loanamt  married_Yes  status_Y
# 1    1.0    4583    128.0            1         0
# 2    1.0    3000     66.0            1         1
# 3    1.0    2583    120.0            1         1
# 4    1.0    6000    141.0            0         1
# 5    1.0    5417    267.0            1         1
# ..   ...     ...      ...          ...       ...
# 609  1.0    2900     71.0            0         1
# 610  1.0    4106     40.0            1         1
# 611  1.0    8072    253.0            1         1
# 612  1.0    7583    187.0            1         1
# 613  0.0    4583    133.0            0         0
#
# [529 rows x 5 columns]

# %%
# Normalize the data (Income and Loan Amount) Using StandardScaler
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
datasetPrep['income']=scaler.fit_transform(datasetPrep[['income']])
datasetPrep['loanamt']=scaler.fit_transform(datasetPrep[['loanamt']])
datasetPrep
# Out:
#       ch    income   loanamt  married_Yes  status_Y
# 1    1.0 -0.128073 -0.194250            1         0
# 2    1.0 -0.392077 -0.971015            1         1
# 3    1.0 -0.461621 -0.294478            1         1
# 4    1.0  0.108246 -0.031380            0         1
# 5    1.0  0.011017  1.547205            1         1
# ..   ...       ...       ...          ...       ...
# 609  1.0 -0.408754 -0.908372            0         1
# 610  1.0 -0.207624 -1.296754            1         1
# 611  1.0  0.453802  1.371807            1         1
# 612  1.0  0.372249  0.544929            1         1
# 613  0.0 -0.128073 -0.131608            0         0
#
# [529 rows x 5 columns]

# %%
# Create the X (Independent) and Y (Dependent) dataframes
Y = datasetPrep[['status_Y']]
X = datasetPrep.drop(['status_Y'], axis=1)

# %%
# Split the X and Y dataset into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = \
train_test_split(X, Y, test_size = 0.3, random_state = 1234, stratify=Y)

# %%
# Import and build Support Vector Classifier
from sklearn import svm
svc=SVC()

clf = svm.SVC(kernel='linear')

# %%
# Predict the outcome using Test data
from sklearn.svm import SVC
svc=SVC()
svc.fit(X_train,Y_train)
Y_predict = svc.predict(X_test)
# Out:
# D:\Python\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# D:\Python\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
# Build the conufsion matrix and get the accuracy/score
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, Y_predict)

score = svc.score(X_test, Y_test)
score
# Out:
# 0.8553459119496856
